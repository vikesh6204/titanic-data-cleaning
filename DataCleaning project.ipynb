# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
#df.fillna(df.median(numeric_only=True),inplace=True)

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])
# Cabin (special case)
df["Cabin"] = df["Cabin"].fillna("Unknown")

#df.fillna(df.mode().iloc[0],inplace=True)

# %%
df.columns=df.columns.str.lower() 
df=df.apply(lambda x:x.str.strip() if x.dtype=="object" else x)

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare    cabin embarked
# 0      0         A/5 21171   7.2500  Unknown        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  Unknown        S
# 3      0            113803  53.1000     C123        S
# 4      0            373450   8.0500  Unknown        S

# %%
df["sex"]=df["sex"].map({"male":0,"female":1})

# %%
df=df.drop_duplicates(subset=["name","age","ticket"])

# %%
num_cols=df.select_dtypes(include=np.number).columns 

for col in num_cols: 
    Q1=df[col].quantile(0.25) 
    Q3=df[col].quantile(0.75) 
    IQR=Q3-Q1 

    lower=Q1 - 1.5*IQR 
    upper=Q3 + 1.5*IQR 

    df[col]=np.where(df[col]<lower,lower,df[col])
    df[col]=np.where(df[col]>upper,upper,df[col]) 

    # Save cleaned data 
    df.to_csv("cleaned_titanic.csv",index=False)

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 name  sex   age  sibsp  parch  \
# 0                            Braund, Mr. Owen Harris  NaN  22.0    1.0    0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  NaN  38.0    1.0    0.0
# 2                             Heikkinen, Miss. Laina  NaN  26.0    0.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  NaN  35.0    1.0    0.0
# 4                           Allen, Mr. William Henry  NaN  35.0    0.0    0.0
#
#              ticket     fare    cabin embarked
# 0         A/5 21171   7.2500  Unknown        S
# 1          PC 17599  65.6344      C85        C
# 2  STON/O2. 3101282   7.9250  Unknown        S
# 3            113803  53.1000     C123        S
# 4            373450   8.0500  Unknown        S
